# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

df = pd.read_csv('data/tiktok_dataset_clean.csv')

# -------------------------
# Рассчитываем вовлечённость
# -------------------------
df['engagement'] = df['video_view_count'] + df['video_like_count'] + df['video_share_count'] + df['video_comment_count'] + df['video_download_count']

# -------------------------
# Топ авторов по вовлечённости
# -------------------------
top_videos = df.nlargest(20, 'engagement')

plt.figure(figsize=(10,6))
sns.barplot(data=top_videos, x='engagement', y='video_id', palette="viridis")
plt.title("Top 20 Videos by Engagement")
plt.xlabel("Engagement")
plt.ylabel("Video ID")
plt.show()

# -------------------------
# Корреляция метрик
# -------------------------
plt.figure(figsize=(6,5))
sns.heatmap(df[['video_like_count','video_share_count','video_view_count','video_comment_count','video_download_count']].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation between Video Metrics")
plt.show()

# -------------------------
# Интерактивная визуализация вовлечённости по времени
# -------------------------
# Если у тебя есть даты публикации, можно добавить график по времени
# px.line(df, x='created_at', y='engagement', title='Engagement Over Time').show()
# Out:
# /var/folders/g7/1d1gzm7d08vcf6yyr91rwrcc0000gn/T/ipykernel_3900/1602610097.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_videos, x='engagement', y='video_id', palette="viridis")
